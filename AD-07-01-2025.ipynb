# %%
s={10,20,30,40,50,60,70,80,90}

# %%
type(s)
# Out:
# set

# %%
s.add(55)
print(s)
# Out:
# {70, 40, 10, 80, 50, 20, 55, 90, 60, 30}

# %%
s
# Out:
# {10, 20, 30, 40, 50, 55, 60, 70, 80, 90}

# %%
s.discard(70)
print(s)
s
# Out:
# {40, 10, 80, 50, 20, 55, 90, 60, 30}
# {10, 20, 30, 40, 50, 55, 60, 80, 90}

# %%
s1={10, 20, 30, 40, 50, 55, 60, 80, 90}
s2={11, 22, 33, 44, 55, 66, 77 ,88, 99}
print(s1|s2)
# Out:
# {33, 66, 99, 40, 10, 11, 44, 77, 80, 50, 20, 22, 55, 88, 90, 60, 30}

# %%
(s1|s2)
# Out:
# {10, 11, 20, 22, 30, 33, 40, 44, 50, 55, 60, 66, 77, 80, 88, 90, 99}

# %%
s1 >= s2
# Out:
# False

# %%
s1 <= s2
# Out:
# False

# %%
list(s1)
# Out:
# [40, 10, 80, 50, 20, 55, 90, 60, 30]

# %%
t=[40, 10, 80, 50, 20, 55, 90, 60, 30]
type(t)
# Out:
# list

# %%
set(t)
# Out:
# {10, 20, 30, 40, 50, 55, 60, 80, 90}

# %%
tuple(t)
# Out:
# (40, 10, 80, 50, 20, 55, 90, 60, 30)

# %%
a={10, 20, 30, 40, 50, 55, 60, 80, 90}
b=(tuple(a))
print(b)
# Out:
# (40, 10, 80, 50, 20, 55, 90, 60, 30)
