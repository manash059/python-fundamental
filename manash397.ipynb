# %%
a=[1,2]

# %%
type(a)
# Out:
# list

# %%
m=['mumbai',45,21,'mexico']

# %%
type(m)
# Out:
# list

# %%
m[0:4]
# Out:
# ['mumbai', 45, 21, 'mexico']

# %%
m[0:-1]
# Out:
# ['mumbai', 45, 21]

# %%
c=[a+m]
print(c)
# Out:
# [[1, 2, 'mumbai', 45, 21, 'mexico']]

# %%
g=[1, 2, 'mumbai', 45, 21, 'mexico']
g[-4]
# Out:
# 'mumbai'

# %%
h=[203, 'hyderbad', 45, True, 'america', False, 78, 'mumbai', 175]
h.insert(6,'India')

# %%
print(h)
# Out:
# [203, 'hyderbad', 45, True, 'america', False, 'India', 78, 'mumbai', 175]

# %%
h.pop(3)
# Out:
# True

# %%
h
# Out:
# [203, 'hyderbad', 45, 'america', False, 'India', 78, 'mumbai', 175]

# %%
h.append('manali')

# %%
print(h)
# Out:
# [203, 'hyderbad', 45, 'america', False, 'India', 78, 'mumbai', 175, 'manali']

# %%
h.remove('India')
print(h)
# Out:
# [203, 'hyderbad', 45, 'america', False, 78, 'mumbai', 175, 'manali']
